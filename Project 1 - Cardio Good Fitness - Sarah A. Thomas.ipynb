# %% [markdown]
# # Sarah Thomas
# # Project 1 - Cardio Good Fitness

# %% [markdown]
# __Description__ (copied from assignment)
#
# __Objective__ - Preliminary Data Analysis. Explore the dataset and practice extracting basic observations about the data. The idea is for you to get comfortable working in Python.
#
# You are expected to do the following :
#
# 1. Come up with a customer profile (characteristics of a customer) of the different products
# 2. Perform uni-variate and multi-variate analyses
# 3. Generate a set of insights and recommendations that will help the company in targeting new customers
#
# __Context__ - The data is for customers of the treadmill product(s) of a retail store called Cardio Good Fitness. It contains the following variables
#
# 1. Product - the model no. of the treadmill
# 2. Age - in no of years, of the customer
# 3. Gender - of the customer
# 4. Education - in no. of years, of the customer
# 5. Marital Status - of the customer
# 6. Usage - Avg. # times the customer wants to use the treadmill every week
# 7. Fitness - Self rated fitness score of the customer (5 - very fit, 1 - very unfit)
# 8. Income - of the customer
# 9. Miles- expected to run
#
# Explore the dataset to identify differences between customers of each product. You can also explore relationships between the different attributes of customers. You can approach it from any other line of questioning that you feel could be relevant for the business.
#
# __Minimum Steps for exploration:__
#
# 1. Importing the dataset into Python & understanding the structure of the dataset
# 2. Basic summary of data and graphical exploration
# 3. Observations from the dataset

# %% [markdown]
# # 1 - Load Packages and Read In the Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set(style="darkgrid")
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore') #filter out warnings

# %%
cardiogood = pd.read_csv('CardioGoodFitness.csv')

# %% [markdown]
# # 2 - Initial Exploration of the Dataset

# %% [markdown]
# ## 2.1 - Check the first and last 10 rows of the dataset

# %%
cardiogood.head(10)
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47
# 5   TM195   20  Female         14     Partnered      3        3   32973     66
# 6   TM195   21  Female         14     Partnered      3        3   35247     75
# 7   TM195   21    Male         13        Single      3        3   32973     85
# 8   TM195   21    Male         15        Single      5        4   35247    141
# 9   TM195   21  Female         15     Partnered      2        3   37521     85

# %%
cardiogood.tail(10)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 170   TM798   31    Male         16     Partnered      6        5   89641
# 171   TM798   33  Female         18     Partnered      4        5   95866
# 172   TM798   34    Male         16        Single      5        5   92131
# 173   TM798   35    Male         16     Partnered      4        5   92131
# 174   TM798   38    Male         18     Partnered      5        5  104581
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 170    260
# 171    200
# 172    150
# 173    360
# 174    150
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %% [markdown]
# __Observation:__ Data looks clean and consistent with what was provided in the description.

# %% [markdown]
# ## 2.2 - Check the shape of the data

# %%
cardiogood.shape
# Out:
# (180, 9)

# %% [markdown]
# __Observation:__ The dataset has 180 rows and 9 columns.

# %% [markdown]
# ## 2.3 - Check the datatype of the variables

# %%
cardiogood.dtypes
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %% [markdown]
# __Observation:__ Data appears to be read in the proper format.

# %% [markdown]
# ## 2.4 - Analyze quantitative variables

# %%
cardiogood.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %% [markdown]
# __Observations:__
# 1. The mean age is only slightly above the median, indicating that the distribution is slightly skewed to the right.
# 2. The 25% quantile (Q1) for Education is 14, meaning that 75% customers have at least an associate's degree.
# 3. The mean for usage is 3.46, only slightly above the median of 3.00 indicating distribution is slightly skewed to the right.
# 4. Customer income is wide-ranging from approx 16507 to 104581.
# 5. Number of miles expected to run is wide-ranging from 21 to 360.

# %% [markdown]
# # 3.0 - Univariate Analysis

# %% [markdown]
# ## 3.1 - Product

# %%
sns.countplot(cardiogood["Product"])
plt.show()

# %% [markdown]
# __Observation:__ TM195 is the most popular model of treadmill.

# %% [markdown]
# ## 3.2 - Age

# %%
sns.distplot(cardiogood['Age'])
plt.show()
sns.boxplot(x='Age', data=cardiogood)
plt.show()

# %% [markdown]
# __Observations:__
# Most customers are in their mid-twenties. As age grows the number of customers lessens through the age of 50. Age is skewed to the right.

# %% [markdown]
# ## 3.3 - Gender

# %%
sns.countplot(cardiogood['Gender'])
plt.show()

# %% [markdown]
# __Observation:__ There are more male than female customers.

# %% [markdown]
# ## 3.4 - Education

# %%
sns.distplot(cardiogood['Education'])
plt.show()
sns.boxplot(x='Education', data=cardiogood)
plt.show()

# %% [markdown]
# __Observations:__
# According to the histogram we can say that most customers have 4 years of college (16 years of education) and a secondary majority have 2 years of college (14 years of education). Using the boxplot we can say that 50% of the customers (IQR) have between 2-4 years of college education.

# %% [markdown]
# ## 3.5 - Martial Status

# %%
sns.countplot(cardiogood['MaritalStatus'])
plt.show()

# %% [markdown]
# __Observation:__ The majority of customers are partnered.

# %% [markdown]
# ## 3.6 - Usage

# %%
sns.distplot(cardiogood['Usage'])
plt.show()
sns.boxplot(x='Usage', data=cardiogood)
plt.show()

# %% [markdown]
# __Observations:__
# 50% of customers want to use the equipment 3-4 times per week. Most customers want to use their treadmill 3 times per week.

# %% [markdown]
# ## 3.7 - Fitness

# %%
sns.distplot(cardiogood['Fitness'])
plt.show()
sns.boxplot(x='Fitness', data=cardiogood)
plt.show()

# %% [markdown]
# __Observations:__ The vast majority of customers rate themselves as 3 (moderately fit) in terms of fitness. 50% of customers rate themselves from 3 to 4.

# %% [markdown]
# ## 3.8 - Income

# %%
sns.distplot(cardiogood['Income'])
plt.show()
sns.boxplot(x='Income', data=cardiogood)
plt.show()

# %% [markdown]
# __Observations:__ Income is right skewed. 50% of customers earn between 45,000-nearly 60,000. The median is near 50,000.

# %% [markdown]
# ## 3.9 - Miles

# %%
sns.distplot(cardiogood['Miles'])
plt.show()
sns.boxplot(x='Miles', data=cardiogood)
plt.show()

# %% [markdown]
# __Observations:__ The number of miles is skewed right. The median is near 100 miles.

# %% [markdown]
# # 4.0 - Multivariate Analysis

# %% [markdown]
# ## 4.1 - Product, Age

# %%
sns.stripplot(cardiogood['Product'],cardiogood['Age'])
plt.show()
sns.boxplot(cardiogood['Product'], cardiogood['Age'])
plt.show()

# to work with exact values
df = cardiogood.groupby('Product')
df.first()

print("TM195")
print(df.get_group('TM195').describe())
print("")
print("TM498")
print(df.get_group('TM498').describe())
print("")
print("TM798")
print(df.get_group('TM798').describe())
# Out:
# TM195
#              Age  Education      Usage   Fitness       Income       Miles
# count  80.000000  80.000000  80.000000  80.00000     80.00000   80.000000
# mean   28.550000  15.037500   3.087500   2.96250  46418.02500   82.787500
# std     7.221452   1.216383   0.782624   0.66454   9075.78319   28.874102
# min    18.000000  12.000000   2.000000   1.00000  29562.00000   38.000000
# 25%    23.000000  14.000000   3.000000   3.00000  38658.00000   66.000000
# 50%    26.000000  16.000000   3.000000   3.00000  46617.00000   85.000000
# 75%    33.000000  16.000000   4.000000   3.00000  53439.00000   94.000000
# max    50.000000  18.000000   5.000000   5.00000  68220.00000  188.000000
#
# TM498
#              Age  Education      Usage   Fitness        Income       Miles
# count  60.000000  60.000000  60.000000  60.00000     60.000000   60.000000
# mean   28.900000  15.116667   3.066667   2.90000  48973.650000   87.933333
# ...

# %% [markdown]
# __Observations:__
# 1. TM195 is the most popular model with the age range spanning 18 to 47 (outlier of 50 exists).
# 2. TM498 is popular among a similar age range as that of TM195, 19 to 45 (outlier of 48 exists).
# 3. TM798 is popular among a narrower range of customers, 22 to 38 (outliers exist from 40 to 48).

# %% [markdown]
# ## 4.2 - Product, Gender

# %%
sns.countplot(x='Product',hue='Gender',data=cardiogood)
plt.show()

# %% [markdown]
# __Observations:__ Male and female customers nearly equally bought TM195 and TM498 but TM798 was much more popular among male customers.

# %% [markdown]
# ## 4.3 - Product, Usage

# %%
sns.stripplot(cardiogood['Product'],cardiogood['Usage'])
plt.show()
sns.boxplot(cardiogood['Product'], cardiogood['Usage'])
plt.show()

# %% [markdown]
# __Observations:__
# 1. TM798 customers plan to use their equipment the most at 3-6 times per week, with an outlier of 7 times per week.
# 2. Next, outside a few outliers, TM498 customers plan to use their equipment at 3 times per week.
# 3. Finally, TM195 customers plan to use their equipment 2-5 times per week.

# %% [markdown]
# ## 4.4 - Product, Fitness

# %%
sns.stripplot(cardiogood['Product'],cardiogood['Fitness'])
plt.show()
sns.boxplot(cardiogood['Product'], cardiogood['Fitness'])
plt.show()

# %% [markdown]
# __Observations:__ Fitness levels are similar for TM195 and TM498 customers (level 3) but the range is higher for customers of TM798 (3-5).

# %% [markdown]
# ## 4.5 - Product, Income

# %%
sns.stripplot(cardiogood['Product'],cardiogood['Income'])
plt.show()
sns.boxplot(cardiogood['Product'], cardiogood['Income'])
plt.show()

# %% [markdown]
# __Observations:__ TM195 (29,562-68,220) and TM498 (31,836-67,083) customers fall into similar income ranges. TM798 customers have higher incomes (48,556-104,581).

# %% [markdown]
# ## 4.6 - Product, Miles

# %%
sns.stripplot(cardiogood['Product'],cardiogood['Miles'])
plt.show()
sns.boxplot(cardiogood['Product'], cardiogood['Miles'])
plt.show()

# %% [markdown]
# __Observations:__
# 1. TM498 customers walk the lowest range of miles (21-125), with a few outliers (175 and 212).
# 2. TM195 customers walk a similar but slightly higher range of miles compared to TM498 (38-147), with outliers ranging up to 188.
# 3. TM798 customers walk a higher number of miles than the customers of the other two models at 80-300 miles, with an outlier of 360.

# %% [markdown]
# ## 4.7 - Correlation

# %%
sns.pairplot(cardiogood)

# %%
correlation = cardiogood.corr()
correlation
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %%
sns.heatmap(correlation, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# __Observations:__ The following are pairs of variables that show higher correlation with an asterisk next to the highest correlations, which will be plotted below.
#
# * Income, Age - 0.51
# * Usage, Education - 0.4
# * Fitness, Education - 0.41
# * Income, Education - 0.63
# * Miles, Usage - 0.76*
# * Income, Usage - 0.52
# * Fitness, Usage - 0.67*
# * Income, Fitness - 0.54
# * Fitness, Miles - 0.79*
# * Income, Miles - 0.54

# %% [markdown]
# ### 4.7.1 - Miles, Usage, Product

# %%
plt.figure(figsize = (15,10))
sns.barplot(x='Usage', y='Miles', data=cardiogood)
plt.show()

plt.figure(figsize = (15,10))
sns.barplot(x='Usage', y='Miles', data=cardiogood, hue='Product')
plt.show()

# %% [markdown]
# __Observations:__ From the top graph we see that growth in intended usage correlates with growth in intended miles. We might expect this. Interestingly from the next graph, we see that higher usage and higher miles correspond with the more frequent purchase of TM798 model. Those with intended usage of 6-7 times per weeks only purchase TM798.

# %% [markdown]
# ## 4.7.2 - Miles, Fitness, Product

# %%
plt.figure(figsize = (15,10))
sns.barplot(x='Fitness', y='Miles', data=cardiogood)
plt.show()

plt.figure(figsize = (15,10))
sns.barplot(x='Fitness', y='Miles', data=cardiogood, hue='Product')
plt.show()

# %% [markdown]
# __Observations:__ From the first graph, we see that higher fitness levels correlate with higher intended miles. This makes sense and might be expected. From the second graph, we see that higher fitness level and intended miles correspond to higher frequency of purchase of the TM798 and secondarily the TM195.

# %% [markdown]
# ## 4.7.3 - Fitness, Usage, Product

# %%
plt.figure(figsize = (15,10))
sns.barplot(x='Fitness', y='Usage', data=cardiogood)
plt.show()

plt.figure(figsize = (15,10))
sns.barplot(x='Fitness', y='Usage', data=cardiogood, hue='Product')
plt.show()

# %% [markdown]
# __Observations:__ From the first graph we see that higher intended usage correlates with higher self-identified fitness level. This might be expected. From the second graph, we see that those with higher fitness levels and higher intended usage purchase the TM798 at higher frequency, with TM195 purchased at the next highest frequency.

# %% [markdown]
# # 5.0 Conclusions

# %% [markdown]
# ## Overall customer profile
# 1. Most customers are in their mid-twenties. As age grows the number of customers lessens through the age of 50. Age is skewed to the right.
# 2. There are more male than female customers.
# 3. 75% customers have at least an associate's degree. Most customers have 4 years of college (16 years of education) and a secondary majority have 2 years of college (14 years of education). 50% of the customers (IQR) have between 2-4 years of college education.
# 4. The majority of customers are partnered.
# 5. The mean for usage is 3.46, only slightly above the median of 3.00 indicating distribution is slightly skewed to the right. 50% of customers want to use the equipment at least 3-4 times per week. Most customers want to use their treadmill at least 3 times per week.
# 6. The vast majority of customers rate themselves as 3 (moderately fit) in terms of fitness. 50% of customers rate themselves from 3 to 4.
# 7. Customer income is wide-ranging from approx 16,507 to 104,581. 50% of customers earn between 45,000-nearly 60,000. The median is near 50,000.
# 8. Number of miles expected to run is wide-ranging from 21 to 360. The median is near 100 miles.
#
# ## Profile for TM195 Customers
# 1. TM195 is the most popular model with the age range spanning 18 to 47 (outlier of 50 exists).
# 2. Male and female customers are nearly equal.
# 3. TM195 customers plan to use their equipment 2-5 times per week.
# 4. The average customer rates his/her fitness level as 3.
# 5. The income range for customers is 29,562-68,220.
# 6. TM195 customers walk a similar but slightly higher range of miles compared to TM498 (38-147), with outliers ranging up to 188.
#
#
# ## Profile for TM498 Customers
# 1. TM498 is popular among a similar age range as that of TM195, 19 to 45 (outlier of 48 exists).
# 2. Male and female customers are nearly equal.
# 3. Outside a few outliers, TM498 customers plan to use their equipment at 3 times per week.
# 4. The average customer rates his/her fitness level as 3.
# 5. The income range for customers is 31,836-67,083.
# 6. TM498 customers walk the lowest range of miles (21-125), with a few outliers (175 and 212).
#
# ## Profile for TM798 Customers
# 1. TM798 is popular among a narrower range of customers, 22 to 38 (outliers exist from 40 to 48).
# 2. This model is more popular among male customers.
# 3. TM798 customers plan to use their equipment the most at 3-6 times per week, with an outlier of 7 times per week.
# 4. Customers rate themselves 3-5 in terms of fitness level.
# 5. The income range for customers, the highest of the products, is 48,556-104,581.
# 6. TM798 customers walk a higher number of miles than the customers of the other two models at 80-300 miles, with an outlier of 360.
